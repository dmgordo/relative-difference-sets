# %% [markdown]
# # Relative Difference Sets
#
# Let $G$ be a group of order $mn$, and $N$ a normal subgroup of $G$ of order $n$. An $(m,n,k,\lambda)$-relative difference set in $G$ relative to $N$ is a subset
# $\{d_1, d_2, \ldots,d_k\}$ of $G$ such that $R=\sum d_i$ in the group
# ring $\mathbb{Z}[G]$ satisfies
#
# $$R R^{-1} = k + \lambda (G-N).$$
#
# This repository contains existence results for relative difference sets in cyclic groups with $k \leq 256$.  This extends earlier computations of Lam (up to $k=50$) and Pott (up to $k=64$ with $n$ odd).
#
#
#
# This notebook contains data on relative difference sets in yaml format, and simple code to access it.  The first line of the notebook reads in the dataset and code.

# %%
# %run 'rds_code.py'
# Out:
# read 548 data items

# %% [markdown]
# This cell lets you search the dataset for ranges of relative difference sets, or ones with a certain existence status.  To get information on certain ones, substitute numbers of interest in the ranges of $m$, $n$, $k$, and $\lambda$.

# %%
T = init_tab()
for R in relative_diffsets:
    m = get_m(R)
    n = get_n(R)
    k = get_k(R)
    lam = get_lam(R)
    if get_status(R) in ['All','Yes']: # look at ones we know exist
        if m in range(1000):
            if n in range(2,50):
                if k in range(257):
                    if lam in range(1,k):
                        add_tab_entry(T,R)                            
show_tab(T)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2a99f">
#   <thead>
#     <tr>
#       <th id="T_2a99f_level0_col0" class="col_heading level0 col0" >m</th>
#       <th id="T_2a99f_level0_col1" class="col_heading level0 col1" >n</th>
#       <th id="T_2a99f_level0_col2" class="col_heading level0 col2" >k</th>
#       <th id="T_2a99f_level0_col3" class="col_heading level0 col3" >lambda</th>
#       <th id="T_2a99f_level0_col4" class="col_heading level0 col4" >status</th>
#       <th id="T_2a99f_level0_col5" class="col_heading level0 col5" >comment</th>
#       <th id="T_2a99f_level0_col6" class="col_heading level0 col6" >set</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2a99f_row0_col0" class="data row0 col0" >7</td>
#       <td id="T_2a99f_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_2a99f_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_2a99f_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_2a99f_row0_col4" class="data row0 col4" >All</td>
#       <td id="T_2a99f_row0_col5" class="data row0 col5" >Lam (1977)</td>
#       <td id="T_2a99f_row0_col6" class="data row0 col6" >[6, 7, 10, 12]</td>
#     </tr>
#     <tr>
#       <td id="T_2a99f_row1_col0" class="data row1 col0" >13</td>
#       <td id="T_2a99f_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_2a99f_row1_col2" class="data row1 col2" >9</td>
#       <td id="T_2a99f_row1_col3" class="data row1 col3" >3</td>
#       <td id="T_2a99f_row1_col4" class="data row1 col4" >All</td>
#       <td id="T_2a99f_row1_col5" class="data row1 col5" >Lam (1977)</td>
#       <td id="T_2a99f_row1_col6" class="data row1 col6" >[1, 2, 3, 6, 8, 9, 18, 20, 24]</td>
#     </tr>
#     <tr>
#       <td id="T_2a99f_row2_col0" class="data row2 col0" >13</td>
#       <td id="T_2a99f_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_2a99f_row2_col2" class="data row2 col2" >9</td>
#       <td id="T_2a99f_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_2a99f_row2_col4" class="data row2 col4" >All</td>
#       <td id="T_2a99f_row2_col5" class="data row2 col5" >Lam (1977)</td>
#       <td id="T_2a99f_row2_col6" class="data row2 col6" >[5, 8, 14, 15, 16, 19, 20, 22, 24]</td>
#     </tr>
#     <tr>
#       <td id="T_2a99f_row3_col0" class="data row3 col0" >21</td>
#       <td id="T_2a99f_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_2a99f_row3_col2" class="data row3 col2" >16</td>
#       <td id="T_2a99f_row3_col3" class="data row3 col3" >6</td>
#       <td id="T_2a99f_row3_col4" class="data row3 col4" >All</td>
#       <td id="T_2a99f_row3_col5" class="data row3 col5" >Lam (1977)</td>
#       <td id="T_2a99f_row3_col6" class="data row3 col6" >[0, 2, 4, 5, 8, 16, 17, 32, 54, 64, 73, 83, 90, 97, 103, 108]</td>
#     </tr>
#     <tr>
#       <td id="T_2a99f_row4_col0" class="data row4 col0" >21</td>
#       <td id="T_2a99f_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_2a99f_row4_col2" class="data row4 col2" >16</td>
#       <td id="T_2a99f_row4_col3" class="data row4 col3" >4</td>
#       <td id="T_2a99f_row4_col4" class="data row4 col4" >All</td>
#       <td id="T_2a99f_row4_col5" class="data row4 col5" >Lam (1977)</td>
#       <td id="T_2a99f_row4_col6" class="data row4 col6" >[0, 2, 4, 5, 8, 16, 17, 32, 54, 64, 73, 83, 90, 97, 103, 108]</td>
#     </tr>
#     <tr>
#       <td id="T_2a99f_row5_col0" class="data row5 col0" >21</td>
#       <td id="T_2a99f_row5_col1" class="data row5 col1" >6</td>
#       <td id="T_2a99f_row5_col2" class="data row5 col2" >16</td>
#       <td id="T_2a99f_row5_col3" class="data row5 col3" >2</td>
#       <td id="T_2a99f_row5_col4" class="data row5 col4" >All</td>
#       <td id="T_2a99f_row5_col5" class="data row5 col5" >Lam (1977)</td>
#       <td id="T_2a99f_row5_col6" class="data row5 col6" >[0, 2, 4, 5, 8, 16, 17, 32, 54, 64, 73, 83, 90, 97, 103, 108]</td>
#     </tr>
#     <tr>
#       <td id="T_2a99f_row6_col0" class="data row6 col0" >31</td>
#       <td id="T_2a99f_row6_col1" class="data row6 col1" >2</td>
#       <td id="T_2a99f_row6_col2" class="data row6 col2" >25</td>
#       <td id="T_2a99f_row6_col3" class="data row6 col3" >10</td>
#       <td id="T_2a99f_row6_col4" class="data row6 col4" >All</td>
#       <td id="T_2a99f_row6_col5" class="data row6 col5" >Lam (1977)</td>
#       <td id="T_2a99f_row6_col6" class="data row6 col6" >[2, 10, 12, 38, 44, 48, 49, 50, 52, 60, 63, 66, 67, 73, 82, 84, 87, 89, 93, 96, 108, 109, 116, 117, 121]</td>
#     </tr>
#     <tr>
#       <td id="T_2a99f_row7_col0" class="data row7 col0" >31</td>
#       <td id="T_2a99f_row7_col1" class="data row7 col1" >2</td>
#       <td id="T_2a99f_row7_col2" class="data row7 col2" >25</td>
#       <td id="T_2a99f_row7_col3" class="data row7 col3" >10</td>
#       <td id="T_2a99f_row7_col4" class="data row7 col4" >All</td>
#       <td id="T_2a99f_row7_col5" class="data row7 col5" >Lam (1977)</td>
#       <td id="T_2a99f_row7_col6" class="data row7 col6" >[1, 5, 13, 16, 25, 28, 38, 42, 43, 48, 58, 64, 65, 66, 72, 77, 80, 82, 83, 84, 86, 91, 93, 112, 116]</td>
#     </tr>
#     <tr>
#       <td id="T_2a99f_row8_col0" class="data row8 col0" >31</td>
#       <td id="T_2a99f_row8_col1" class="data row8 col1" >4</td>
#       <td id="T_2a99f_row8_col2" class="data row8 col2" >25</td>
#       <td id="T_2a99f_row8_col3" class="data row8 col3" >5</td>
#       <td id="T_2a99f_row8_col4" class="data row8 col4" >All</td>
#       <td id="T_2a99f_row8_col5" class="data row8 col5" >Lam (1977)</td>
#       <td id="T_2a99f_row8_col6" class="data row8 col6" >[2, 10, 12, 38, 44, 48, 49, 50, 52, 60, 63, 66, 67, 73, 82, 84, 87, 89, 93, 96, 108, 109, 116, 117, 121]</td>
#     </tr>
#     <tr>
#       <td id="T_2a99f_row9_col0" class="data row9 col0" >31</td>
#       <td id="T_2a99f_row9_col1" class="data row9 col1" >4</td>
#       <td id="T_2a99f_row9_col2" class="data row9 col2" >25</td>
#       <td id="T_2a99f_row9_col3" class="data row9 col3" >5</td>
#       <td id="T_2a99f_row9_col4" class="data row9 col4" >All</td>
#       <td id="T_2a99f_row9_col5" class="data row9 col5" >Lam (1977)</td>
#       <td id="T_2a99f_row9_col6" class="data row9 col6" >[1, 5, 13, 16, 25, 28, 38, 42, 43, 48, 58, 64, 65, 66, 72, 77, 80, 82, 83, 84, 86, 91, 93, 112, 116]</td>
#     </tr>
#     <tr>
#       <td id="T_2a99f_row10_col0" class="data row10 col0" >31</td>
#       <td id="T_2a99f_row10_col1" class="data row10 col1" >2</td>
#       <td id="T_2a99f_row10_col2" class="data row10 col2" >16</td>
#       <td id="T_2a99f_row10_col3" class="data row10 col3" >4</td>
#       <td id="T_2a99f_row10_col4" class="data row10 col4" >All</td>
#       <td id="T_2a99f_row10_col5" class="data row10 col5" >Lam (1977)</td>
#       <td id="T_2a99f_row10_col6" class="data row10 col6" >[3, 10, 17, 18, 20, 22, 26, 31, 36, 37, 40, 42, 43, 44, 52, 55]</td>
#     </tr>
#     <tr>
#       <td id="T_2a99f_row11_col0" class="data row11 col0" >31</td>
#       <td id="T_2a99f_row11_col1" class="data row11 col1" >2</td>
#       <td id="T_2a99f_row11_col2" class="data row11 col2" >16</td>
#       <td id="T_2a99f_row11_col3" class="data row11 col3" >4</td>
#       <td id="T_2a99f_row11_col4" class="data row11 col4" >All</td>
#       <td id="T_2a99f_row11_col5" class="data row11 col5" >Lam (1977)</td>
#       <td id="T_2a99f_row11_col6" class="data row11 col6" >[6, 10, 11, 12, 13, 18, 20, 21, 24, 31, 34, 36, 40, 48, 53, 57]</td>
#     </tr>
#     <tr>
#       <td id="T_2a99f_row12_col0" class="data row12 col0" >40</td>
#       <td id="T_2a99f_row12_col1" class="data row12 col1" >2</td>
#       <td id="T_2a99f_row12_col2" class="data row12 col2" >27</td>
#       <td id="T_2a99f_row12_col3" class="data row12 col3" >9</td>
#       <td id="T_2a99f_row12_col4" class="data row12 col4" >All</td>
#       <td id="T_2a99f_row12_col5" class="data row12 col5" >Lam (1977)</td>
#       <td id="T_2a99f_row12_col6" class="data row12 col6" >[7, 13, 16, 17, 21, 22, 29, 31, 32, 34, 37, 38, 39, 40, 44, 48, 50, 51, 52, 59, 63, 64, 66, 68, 70, 73, 76]</td>
#     </tr>
#     <tr>
#       <td id="T_2a99f_row13_col0" class="data row13 col0" >40</td>
#       <td id="T_2a99f_row13_col1" class="data row13 col1" >2</td>
#       <td id="T_2a99f_row13_col2" class="d

# %% [markdown]
# ## Viewing existence results and relative difference sets
#
# After reading the data in <code>rds.json</code>, <code>rds_code.py</code> gives functions to check for relative difference sets $R$ in the dataset.
#
# The arguments to <code>get_rds_data()</code> are $m$, $n$, $k$, and $\lambda$,

# %%
get_rds_data(13,2,9,3)
# Out:
# There are exactly 2 cyclic (13,2,9,3)-RDS
# Reference: Lam (1977)
#
# 0:	R = [1, 2, 3, 6, 8, 9, 18, 20, 24]
# 1:	R = [5, 8, 14, 15, 16, 19, 20, 22, 24]

# %% [markdown]
# ## Handling relative difference sets
#
# The above functions are to get information about results in the database.  If you want to get the actual objects to manipulate, <code>get_rds</code>$(m,n,k,\lambda,i)$ returns the $i$th such relative difference set in the database, as a list $[m,n,k,\lambda,R]$.

# %%
D=get_rds(21,6,16,2,0)
print(D)
# Out:
# [21, 6, 16, 2, [0, 2, 4, 5, 8, 16, 17, 32, 54, 64, 73, 83, 90, 97, 103, 108]]
